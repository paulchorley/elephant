# %% [markdown]
# ## Initialization

# %%
import sys
sys.path.append('..')

import numpy as np
import quantities as pq
import matplotlib.pyplot as plt

# provides data model for ephys data
import neo

# analysis library component
import elephant

# provides plots of the results
import plots

# %matplotlib inline

# %%
reload(elephant.conversion)
reload(elephant.statistics)
reload(plots)
# Out:
# <module 'plots' from 'plots.pyc'>

# %% [markdown]
# ## Load experimental data

# %%
# data should be in a subdirectory 'data' relative to this notebook's location
session = neo.io.BlackrockIO("data/i140701-004")
block = session.read_block(n_starts=[10*pq.s],n_stops=[20*pq.s],channel_list=[], units=[1,2,3])
sts_exp = [ st for st in block.segments[0].spiketrains if len(st) > 2 ]

# %%
print("Number of experimental spiketrains: "+str(len(sts_exp)))
# Out:
# Number of experimental spiketrains: 147

# %% [markdown]
# ## Load simulation data

# %%
# data should be in a subdirectory 'data' relative to this notebook's location
# TODO: Convert data to a hdf5 file and load it via neo.io.hdf5io
sts = np.load('data/sts_mdl.npy')
mdl_t_start = 0*pq.s
mdl_t_stop = 10*pq.s
n_mdl = 150
s_start = int(mdl_t_start.rescale(pq.ms).magnitude)
s_stop = int(mdl_t_stop.rescale(pq.ms).magnitude)
sts_mdl = [ neo.SpikeTrain(st[(st>=s_start)&(st<s_stop)],
                           t_start = mdl_t_start, t_stop = mdl_t_stop,
                           units = pq.ms) for st in sts[:n_mdl] ]

# %%
print("Number of simulation spiketrains: "+str(len(sts_mdl)))
# Out:
# Number of simulation spiketrains: 150

# %% [markdown]
# ## Plot population activity rasters

# %%
plt.figure(figsize=(16,8))
plt.suptitle('Population Spike Activity',fontsize=14)

plt.subplot(2,1,1)
plt.title('Experiment')
plots.spike_raster(sts_exp)

plt.subplot(2,1,2)
plt.title('Model')
plots.spike_raster(sts_mdl)

plt.subplots_adjust(hspace=0.5)

# %%
phist_exp = elephant.statistics.peth(sts_exp, 100*pq.ms, output='rate')
phist_mdl = elephant.statistics.peth(sts_mdl, 100*pq.ms, output='rate')

# %%
plt.figure(figsize=(16,6))
plt.suptitle('Population Spike Rate',fontsize=14)

plt.subplot(2,1,1)
plt.title('Experiment')
plots.population_rate(phist_exp)

plt.subplot(2,1,2)
plt.title('Model')
plots.population_rate(phist_mdl)

plt.subplots_adjust(hspace=0.5)

# %%
rates_exp = [ elephant.statistics.mean_firing_rate(st) for st in sts_exp ]
rates_mdl = [ elephant.statistics.mean_firing_rate(st) for st in sts_mdl ]

# %%
plt.figure(figsize=(16,4))
plt.suptitle('Mean Firing Rate Distribution',fontsize=14)

plt.subplot(1,2,1)
plt.title('Experiment')
plots.rate_distribution(rates_exp,bin_width=2*pq.Hz)

plt.subplot(1,2,2)
plt.title('Model')
plots.rate_distribution(rates_mdl,bin_width=0.25*pq.Hz)

plt.subplots_adjust(hspace=0.5)

# %%
isis_exp = [ elephant.statistics.isi(st) for st in sts_exp ]
isis_mdl = [ elephant.statistics.isi(st) for st in sts_mdl ]

# %%
601, 0.97356979295839308, 0.8925722506107393, 0.77398476588859755, 0.66647984828539997, 0.80382629566021435, 1.2274529752040266, 0.85084469008359565, 0.7875563916488979, 1.1990531714817276, 0.52296761580375284, 0.75357344814620641, 0.93112000450932864, 0.82796406058808503, 0.9912777058193869, 1.1887657848993896, 0.7525333541682061, 1.0829367431350192, 0.86468579049760841, 0.86471096276273529, 0.77226094919984811, 0.38473599396059871, 0.94020935514162562, 0.88092858852178735, 1.1412098372895678, 0.87693538053775832, 0.95385805454842798, 0.99390833887093655, 1.1790019378305066]

# %%
plt.figure(figsize=(16,4))
plt.suptitle('CV Distribution',fontsize=14)

plt.subplot(1,2,1)
plt.title('Experiment')
plots.cv_distribution(cvs_exp,n_bins=25)

plt.subplot(1,2,2)
plt.title('Model')
plots.cv_distribution(cvs_mdl,n_bins=25)

plt.subplots_adjust(hspace=0.5)

# %%
lvs_exp = [ elephant.statistics.lv(isi) for isi in isis_exp ]
lvs_mdl = [ elephant.statistics.lv(isi) for isi in isis_mdl ]
print lvs_exp
# Out:
# [array(0.17220617057885027) * dimensionless, array(1.1178399552660203) * dimensionless, array(0.7891485702293146) * dimensionless, array(0.0652497086524506) * dimensionless, array(1.206303856638552) * dimensionless, array(0.9402315657301427) * dimensionless, array(0.7534731966417012) * dimensionless, array(0.8307078967572774) * dimensionless, array(0.8613696022570984) * dimensionless, array(2.358022501949596) * dimensionless, array(0.6987342868542274) * dimensionless, array(0.9446712344944288) * dimensionless, array(0.9793787130153736) * dimensionless, array(1.212726780614061) * dimensionless, array(0.2721318947101324) * dimensionless, array(0.8278520087081624) * dimensionless, array(0.41124329925886616) * dimensionless, array(1.031844006930898) * dimensionless, array(0.3288465689110138) * dimensionless, array(0.6529626886522618) * dimensionless, array(0.8848638981971839) * dimensionless, array(0.1090023094575021) * dimensionless, array(0.907798642079981) * dimensionless, array(1.1374756333548333) * dimensionless, array(1.3878185692546883) * dimensionless, array(0.4058565292722279) * dimensionless, array(0.5597652945399902) * dimensionless, array(0.3369994851658718) * dimensionless, array(0.6013965717560702) * dimensionless, array(0.5592602734366684) * dimensionless, array(1.1345677638268046) * dimensionless, array(0.9154712410784266) * dimensionless, array(0.682498402827204) * dimensionless, array(1.4330286420787732) * dimensionless, array(1.0233928271072976) * dimensionless, array(0.9148205121498435) * dimensionless, array(0.8008193160739564) * dimensionless, array(0.40479237637125476) * dimensionless, array(0.6281907787589028) * dimensionless, array(0.8748888405556758) * dimensionless, array(0.7546702612252616) * dimensionless, array(0.8499728659165513) * dimensionless, array(0.807351472455963) * dimensionless, array(0.7721507975149104) * dimensionless, array(0.8284880076796134) * dimensionless, array(0.6125038089457341) * dimensionless, array(1.138110056845208) * dimensionless, array(0.596410934129584) * dimensionless, array(0.8077925397023932) * dimensionless, array(1.0397122142872228) * dimensionless, array(0.4130398681292469) * dimensionless, array(1.9637419950240025) * dimensionless, array(0.5355102117573031) * dimensionless, array(0.539178634383901) * dimensionless, array(1.1947917864374207) * dimensionless, array(0.8093779948472171) * dimensionless, array(0.9900856212157594) * dimensionless, array(0.4856544087105063) * dimensionless, array(0.8394759066346771) * dimensionless, array(0.9748501721790295) * dimensionless, array(0.7278756764546093) * dimensionless, array(0.7869559409622638) * dimensionless, array(0.9068652657125522) * dimensionless, array(0.8643485391649579) * dimensionless, array(1.4042315478532221) * dimensionless, array(1.1915793585512438) * dimensionless, array(0.615645294729317) * dimensionless, array(1.3538911930629507) * dimensionless, array(0.10222082885214716) * dimensionless, array(0.7325207083453811) * dimensionless, array(0.4997740013707266) * dimensionless, array(1.494516076948687) * dimensionless, array(0.6301099178941325) * dimensionless, array(0.8094730202146229) * dimensionless, array(1.7012792401765602) * dimensionless, array(0.3307318644414765) * dimensionless, array(0.2965865841176102) * dimensionless, array(1.272662112530016) * dimensionless, array(0.9842614016778445) * dimensionless, array(0.102176961991651) * dimensionless, array(0.7339495852254537) * dimensionless, array(0.2529624226568492) * dimensionless, array(1.0038498164094498) * dimensionless, array(0.8047223488740719) * dimensionless, array(0.23619365655478916) * dimensionless, array(1.6228439802668713) * dimensionless, array(0.8257676877654888) * dimensionless, array(0.7626648696873927) * dimensionless, array(0.8557889417365043) * dimensionless, array(0.8391562686952495) * dimensionless, array(0.5241768390721453) * dimensionless, array(0.8873729826100426) * dimensionless, array(0.6532770111039498) * dimensionless, array(0.4 ...

# %%
plt.figure(figsize=(16,4))
plt.suptitle('LV Distribution',fontsize=14)

plt.subplot(1,2,1)
plt.title('Experiment')
plots.lv_distribution(lvs_exp,n_bins=25)

plt.subplot(1,2,2)
plt.title('Model')
plots.lv_distribution(lvs_mdl,n_bins=25)

plt.subplots_adjust(hspace=0.5)

# %%
cc_matrix_exp = elephant.statistics.corrcoef(sts_exp, binsize = 20*pq.ms, clip=True)
cc_matrix_mdl = elephant.statistics.corrcoef(sts_mdl, binsize = 20*pq.ms, clip=True)
print cc_matrix_exp
# Out:
# [[ 1.          0.00448772 -0.03097976 ...,  0.08715574  0.04956462
#    0.04660316]
#  [ 0.00448772  1.         -0.03721593 ..., -0.07877723  0.00909985
#   -0.03327772]
#  [-0.03097976 -0.03721593  1.         ...,  0.03845827  0.05394562
#    0.03077649]
#  ...,
#  [ 0.08715574 -0.07877723  0.03845827 ...,  1.         -0.09264692
#   -0.01721747]
#  [ 0.04956462  0.00909985  0.05394562 ..., -0.09264692  1.         -0.0393727 ]
#  [ 0.04660316 -0.03327772  0.03077649 ..., -0.01721747 -0.0393727   1.        ]]

# %%
plt.figure(figsize=(16,4))
plt.suptitle('Pairwise Correlation Coeficient Distribution',fontsize=14)

plt.subplot(1,2,1)
plt.title('Experiment')
plots.cc_distribution(cc_matrix_exp,n_bins=50)

plt.subplot(1,2,2)
plt.title('Model')
plots.cc_distribution(cc_matrix_mdl,n_bins=50)

plt.subplots_adjust(hspace=0.5)
